# %% [markdown]
# # Ridge regresion

# %% [markdown]
# ## linear

# %% [markdown]
# ### make data

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
m=50
X = 6*np.random.rand(m,1)-3 #ranedom.rand(m,n)   m*n行列で0以上1未満の乱数を生成する
y=0.9*X+2+np.random.randn(m,1) #random.randn(m,n)   m*n行列で平均0,分散0の乱数を生成する

# %%
plt.figure(facecolor="white")
plt.scatter(X,y)
plt.show()

# %% [markdown]
# ### modeling

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1) # インスタンス化
ridge_reg.fit(X,y)
ridge_reg.intercept_,ridge_reg.coef_
# Out:
# (array([2.35292151]), array([[0.95255644]]))

# %%
plt.figure(facecolor="white")
plt.scatter(X,y)
plt.plot(X,ridge_reg.predict(X),"r-")
plt.show()

# %% [markdown]
# ## Non-linear

# %% [markdown]
# ## make data

# %%
m=50
degree = 4
x = 8*np.random.rand(m,1)-1.5 #ranedom.rand(m,n)   m*n行列で0以上1未満の乱数を生成する
X=np.zeros((m,degree)) #データサイズ*次元数の配列を生成
X[:, 0] = x.T #0列目にzを代入
for i in range(degree-1): #各次元におけるxの値を計算
    X[:,i+1] = X[:,i]*X[:,0]
y = np.sin(X[:,0]).reshape(-1,1)+ np.random.randn(m,1)/2.70 + 8.5  #yを生成

# %%
plt.figure(facecolor="white")
plt.scatter(X.T[0],y)
plt.show()

# %% [markdown]
# ### modeling

# %%
ridge_reg = Ridge(alpha=1)
ridge_reg.fit(X,y)
ridge_reg.intercept_,ridge_reg.coef_
# Out:
# (array([8.6044098]),
#  array([[ 0.8453768 , -0.15684502, -0.07607899,  0.01269251]]))

# %%
plot_num = 200
x_test = np.array([np.arange(-10,10,0.1)]).reshape(plot_num,1) #グラフのためのnumpy配列を生成

X_test=np.zeros((plot_num,degree)) #データサイズ*次元数の配列を生成
X_test[:, 0] = x_test.T #0列目にzを代入
for i in range(degree-1): #各次元におけるxの値を計算
    X_test[:,i+1] = X_test[:,i]*X_test[:,0]

# %%
plt.figure(facecolor="white")
plt.scatter(x,y)
plt.plot(x_test,ridge_reg.predict(X_test),"r-")
plt.xlim(-2,8)
plt.ylim(6.5,10.5)
plt.show()

# %% [markdown]
# ### change hyperparameter

# %%
ridge_reg1 = Ridge(alpha=1)
ridge_reg2 = Ridge(alpha=10)
ridge_reg3 = Ridge(alpha=100)
ridge_reg1.fit(X,y)
ridge_reg2.fit(X,y)
ridge_reg3.fit(X,y)

plt.figure(facecolor="white")
plt.scatter(x,y)
plt.plot(x_test,ridge_reg1.predict(X_test),"r-",label="a=    1")
plt.plot(x_test,ridge_reg2.predict(X_test),"g-",label="a=  10")
plt.plot(x_test,ridge_reg3.predict(X_test),"m-",label="a=100")
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(-2,8)
plt.ylim(6.5,10.5)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Lasso regression

# %% [markdown]
# ## linear

# %% [markdown]
# ### make data

# %%
m=50
X = 6*np.random.rand(m,1)-3 #ranedom.rand(m,n)   m*n行列で0以上1未満の乱数を生成する
y=0.9*X+2+np.random.randn(m,1) #random.randn(m,n)   m*n行列で平均0,分散0の乱数を生成する

# %%
plt.figure(facecolor="white")
plt.scatter(X,y)
plt.show()

# %% [markdown]
# ### modeling

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X,y)
lasso_reg.intercept_,lasso_reg.coef_
# Out:
# (array([2.00054877]), array([0.73818809]))

# %%
plt.figure(facecolor="white")
plt.scatter(X,y)
plt.plot(X,lasso_reg.predict(X),"r-")
plt.show()

# %% [markdown]
# ## Non linear

# %% [markdown]
# ### make data

# %%
m=50
degree = 4
x = 8*np.random.rand(m,1)-1.5 #ranedom.rand(m,n)   m*n行列で0以上1未満の乱数を生成する
X=np.zeros((m,degree)) #データサイズ*次元数の配列を生成
X[:, 0] = x.T #0列目にzを代入
for i in range(degree-1): #各次元におけるxの値を計算
    X[:,i+1] = X[:,i]*X[:,0]
y = np.sin(X[:,0]).reshape(-1,1)+ np.random.randn(m,1)/2.70 + 8.5  #yを生成

# %%
plt.figure(facecolor="white")
plt.scatter(X.T[0],y)
plt.show()

# %% [markdown]
# ### modeling

# %%
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X,y)
lasso_reg.intercept_,lasso_reg.coef_
# Out:
# C:\Users\yudai\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.885039371812261, tolerance: 0.003318490146951137
#   positive)
# (array([8.55658494]),
#  array([ 0.62492681, -0.0608521 , -0.08397724,  0.01234934]))

# %%
plot_num = 200
x_test = np.array([np.arange(-10,10,0.1)]).reshape(plot_num,1) #グラフのためのnumpy配列を生成

X_test=np.zeros((plot_num,degree)) #データサイズ*次元数の配列を生成
X_test[:, 0] = x_test.T #0列目にzを代入
for i in range(degree-1): #各次元におけるxの値を計算
    X_test[:,i+1] = X_test[:,i]*X_test[:,0]

# %%
plt.figure(facecolor="white")
plt.scatter(x,y)
plt.plot(x_test,lasso_reg.predict(X_test),"r-")
plt.xlim(-2,8)
plt.ylim(6.5,10.5)
plt.show()

# %%
lasso_reg1 = Lasso(alpha=10)
lasso_reg2 = Lasso(alpha=1)
lasso_reg3 = Lasso(alpha=0.1)
lasso_reg1.fit(X,y)
lasso_reg2.fit(X,y)
lasso_reg3.fit(X,y)

plt.figure(facecolor="white")
plt.scatter(x,y)
plt.plot(x_test,lasso_reg1.predict(X_test),"r-",label="a= 10")
plt.plot(x_test,lasso_reg2.predict(X_test),"g-",label="a=  1")
plt.plot(x_test,lasso_reg3.predict(X_test),"m-",label="a=0.1")
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(-2,8)
plt.ylim(6.5,10.5)
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\yudai\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.885039371812261, tolerance: 0.003318490146951137
#   positive)
