# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("3Dsample2.csv",header=None)
df = df.rename(columns={0:"step",1:"X",2:"Y",3:"Z",4:"Vx",5:"Vy",6:"Vz"})
df.head()
# Out:
#    step         X         Y         Z        Vx       Vy    Vz
# 0  0.00  0.100000  0.000000  0.000000  0.000000  0.10000  0.00
# 1  0.01  0.100000  0.001005  0.000000  0.002020  0.10000  0.01
# 2  0.02  0.100020  0.002010  0.000101  0.004040  0.09996  0.02
# 3  0.03  0.100061  0.003015  0.000302  0.006059  0.09988  0.03
# 4  0.04  0.100122  0.004018  0.000603  0.008077  0.09976  0.04

# %%
# 3Dでプロット
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(df["X"], df["Y"], df["Z"], "o-", color="#00aa00", ms=4, mew=0.5)

# 軸ラベル
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 表示
plt.show()
